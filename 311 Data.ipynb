# %% [markdown]
# ## 311 Data API Call

# %%
# Import Modules
import requests as rq
import json
from pprint import pprint
from sodapy import Socrata
import pandas as pd

# %%
# Build the endpoint URL
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?"

# %%
response = Socrata("data.cityofnewyork.us", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Run a request to endpoint and convert result to pretty-printed json
results = response.get("erm2-nwe9", limit=10)

# %%
# Pretty-print Json Results
pprint(results)
# Out:
# [{':@computed_region_92fq_4b7q': '22',
#   ':@computed_region_efsh_h5xi': '10935',
#   ':@computed_region_f5dn_yrer': '35',
#   ':@computed_region_sbqj_enih': '31',
#   ':@computed_region_yeji_bk3q': '5',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '2030620021',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '06 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:03:27.000',
#   'cross_street_1': 'EAST  180 STREET',
#   'cross_street_2': 'EAST  181 STREET',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '2111 LAFONTAINE AVENUE',
#   'incident_zip': '10457',
#   'intersection_street_1': 'EAST  180 STREET',
#   'intersection_street_2': 'EAST  181 STREET',
#   'landmark': 'LAFONTAINE AVENUE',
#   'latitude': '40.8505302389672',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.8505302389672',
#                'longitude': '-73.8919374843883'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.8919374843883',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'LAFONTAINE AVENUE',
#   'unique_key': '49782378',
#   'x_coordinate_state_plane': '1014146',
#   'y_coordinate_state_plane': '249167'},
#  {':@computed_region_92fq_4b7q': '15',
#   ':@computed_region_efsh_h5xi': '13826',
#   ':@computed_region_f5dn_yrer': '21',
#   ':@computed_region_sbqj_enih': '35',
#   ':@computed_region_yeji_bk3q': '2',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '3087250001',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '13 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:02:58.000',
#   'cross_street_1': 'CONEY ISLAND AVENUE',
#   'cross_street_2': 'BRIGHTON   15 STREET',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': 'BRIGHTON BEACH',
#   'incident_zip': '11235',
#   'intersection_street_1': 'CONEY ISLAND AVENUE',
#   'intersection_street_2': 'BRIGHTON   15 STREET',
#   'landmark': 'BRIGHTON BEACH',
#   'latitude': '40.57458505962574',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.57458505962574',
#                'longitude': '-73.95845608738573'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.95845608738573',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'BRIGHTON BEACH',
#   'unique_key': '49781595',
#   'x_coordinate_state_plane': '995791',
#   'y_coordinate_state_plane': '148616'},
#  {':@computed_region_92fq_4b7q': '40',
#   ':@computed_region_efsh_h5xi': '11605',
#   ':@computed_region_f5dn_yrer': '24',
#   ':@computed_region_sbqj_enih': '34',
#   ':@computed_region_yeji_bk3q': '5',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '2033350005',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '07 BRONX',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:02:58.000',
#   'cross_street_1': 'BAINBRIDGE AVENUE',
#   'cross_street_2': 'EAST  206 STREET',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '3155 ROCHAMBEAU AVENUE',
#   'incident_zip': '10467',
#   'intersection_street_1': 'BAINBRIDGE AVENUE',
#   'intersection_street_2': 'EAST  206 STREET',
#   'landmark': 'ROCHAMBEAU AVENUE',
#   'latitude': '40.87491928240582',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.87491928240582',
#                'longitude': '-73.880438925099'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.880438925099',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'ROCHAMBEAU AVENUE',
#   'unique_key': '49779959',
#   'x_coordinate_state_plane': '1017315',
#   'y_coordinate_state_plane': '258057'},
#  {':@computed_region_92fq_4b7q': '49',
#   ':@computed_region_efsh_h5xi': '18181',
#   ':@computed_region_f5dn_yrer': '69',
#   ':@computed_region_sbqj_enih': '52',
#   ':@computed_region_yeji_bk3q': '2',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '3016150054',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '03 BROOKLYN',
#   'complaint_type': 'Blocked Driveway',
#   'created_date': '2021-02-14T02:02:53.000',
#   'cross_street_1': 'LEWIS AVENUE',
#   'cross_street_2': 'STUYVESANT AVENUE',
#   'descriptor': 'No Access',
#   'incident_address': '843 GREENE AVENUE',
#   'incident_zip': '11221',
#   'intersection_street_1': 'LEWIS AVENUE',
#   'intersection_street_2': 'STUYVESANT AVENUE',
#   'landmark': 'GREENE AVENUE',
#   'latitude': '40.690335305980504',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.690335305980504',
#                'longitude': '-73.93441535236495'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.93441535236495',
#   'open_data_channel_type': 'PHONE',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'GREENE AVENUE',
#   'unique_key': '49780010',
#   'x_coordinate_state_plane': '1002438',
#   'y_coordinate_state_plane': '190791'},
#  {':@computed_region_92fq_4b7q': '47',
#   ':@computed_region_efsh_h5xi': '20530',
#   ':@computed_region_f5dn_yrer': '51',
#   ':@computed_region_sbqj_enih': '59',
#   ':@computed_region_yeji_bk3q': '3',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '4159260001',
#   'borough': 'QUEENS',
#   'city': 'ARVERNE',
#   'community_board': '14 QUEENS',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:02:42.000',
#   'cross_street_1': 'BOARDWALK',
#   'cross_street_2': 'LARKIN AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '146 BEACH   59 STREET',
#   'incident_zip': '11692',
#   'intersection_street_1': 'BOARDWALK',
#   'intersection_street_2': 'LARKIN AVENUE',
#   'landmark': 'BEACH   59 STREET',
#   'latitude': '40.590633900417814',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.590633900417814',
#                'longitude': '-73.78875579204002'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.78875579204002',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'BEACH   59 STREET',
#   'unique_key': '49780007',
#   'x_coordinate_state_plane': '1042920',
#   'y_coordinate_state_plane': '154531'},
#  {':@computed_region_92fq_4b7q': '34',
#   ':@computed_region_efsh_h5xi': '15310',
#   ':@computed_region_f5dn_yrer': '54',
#   ':@computed_region_sbqj_enih': '62',
#   ':@computed_region_yeji_bk3q': '3',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '4036590005',
#   'borough': 'QUEENS',
#   'city': 'RIDGEWOOD',
#   'community_board': '05 QUEENS',
#   'complaint_type': 'Blocked Driveway',
#   'created_date': '2021-02-14T02:02:00.000',
#   'cross_street_1': '70 AVENUE',
#   'cross_street_2': 'CENTRAL AVENUE',
#   'descriptor': 'No Access',
#   'incident_address': '70-01 69 STREET',
#   'incident_zip': '11385',
#   'intersection_street_1': '70 AVENUE',
#   'intersection_street_2': 'CENTRAL AVENUE',
#   'landmark': '69 STREET',
#   'latitude': '40.705202592283996',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.705202592283996',
#                'longitude': '-73.8842166083503'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.8842166083503',
#   'open_data_channel_type': 'PHONE',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': '69 STREET',
#   'unique_key': '49777488',
#   'x_coordinate_state_plane': '1016352',
#   'y_coordinate_state_plane': '196222'},
#  {':@computed_region_92fq_4b7q': '2',
#   ':@computed_region_efsh_h5xi': '11605',
#   ':@computed_region_f5dn_yrer': '29',
#   ':@computed_region_sbqj_enih': '30',
#   ':@computed_region_yeji_bk3q': '5',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '2046490049',
#   'borough': 'BRONX',
#   'city': 'BRONX',
#   'community_board': '12 BRONX',
#   'complaint_type': 'Blocked Driveway',
#   'created_date': '2021-02-14T02:00:48.000',
#   'cross_street_1': 'EAST  216 STREET',
#   'cross_street_2': 'EAST  219 STREET',
#   'descriptor': 'No Access',
#   'incident_address': '3767 OLINVILLE AVENUE',
#   'incident_zip': '10467',
#   'intersection_street_1': 'EAST  216 STREET',
#   'intersection_street_2': 'EAST  219 STREET',
#   'landmark': 'OLINVILLE AVENUE',
#   'latitude': '40.88343335975521',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.88343335975521',
#                'longitude': '-73.86551317019918'},
#   'location_type': 'Street/Sidewalk',
#   'longitude': '-73.86551317019918',
#   'open_data_channel_type': 'PHONE',
#   'park_borough': 'BRONX',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'OLINVILLE AVENUE',
#   'unique_key': '49783262',
#   'x_coordinate_state_plane': '1021438',
#   'y_coordinate_state_plane': '261165'},
#  {':@computed_region_92fq_4b7q': '21',
#   ':@computed_region_efsh_h5xi': '14510',
#   ':@computed_region_f5dn_yrer': '66',
#   ':@computed_region_sbqj_enih': '68',
#   ':@computed_region_yeji_bk3q': '3',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '4020010041',
#   'borough': 'QUEENS',
#   'city': 'CORONA',
#   'community_board': '04 QUEENS',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:00:40.000',
#   'cross_street_1': '45 AVENUE',
#   'cross_street_2': '46 AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '45-10 111 STREET',
#   'incident_zip': '11368',
#   'intersection_street_1': '45 AVENUE',
#   'intersection_street_2': '46 AVENUE',
#   'landmark': '111 STREET',
#   'latitude': '40.748607199004084',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.748607199004084',
#                'longitude': '-73.85430845454465'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.85430845454465',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'QUEENS',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': '111 STREET',
#   'unique_key': '49780006',
#   'x_coordinate_state_plane': '1024618',
#   'y_coordinate_state_plane': '212048'},
#  {':@computed_region_92fq_4b7q': '45',
#   ':@computed_region_efsh_h5xi': '18184',
#   ':@computed_region_f5dn_yrer': '21',
#   ':@computed_region_sbqj_enih': '35',
#   ':@computed_region_yeji_bk3q': '2',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '3070670001',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '13 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:00:37.000',
#   'cross_street_1': 'WEST   30 STREET',
#   'cross_street_2': 'WEST   31 STREET',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '3020 SURF AVENUE',
#   'incident_zip': '11224',
#   'intersection_street_1': 'WEST   30 STREET',
#   'intersection_street_2': 'WEST   31 STREET',
#   'landmark': 'SURF AVENUE',
#   'latitude': '40.572756248204456',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.572756248204456',
#                'longitude': '-73.99663799059248'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.99663799059248',
#   'open_data_channel_type': 'ONLINE',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'SURF AVENUE',
#   'unique_key': '49780004',
#   'x_coordinate_state_plane': '985184',
#   'y_coordinate_state_plane': '147947'},
#  {':@computed_region_92fq_4b7q': '17',
#   ':@computed_region_efsh_h5xi': '18181',
#   ':@computed_region_f5dn_yrer': '69',
#   ':@computed_region_sbqj_enih': '52',
#   ':@computed_region_yeji_bk3q': '2',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'bbl': '3014810067',
#   'borough': 'BROOKLYN',
#   'city': 'BROOKLYN',
#   'community_board': '03 BROOKLYN',
#   'complaint_type': 'Noise - Residential',
#   'created_date': '2021-02-14T02:00:14.000',
#   'cross_street_1': 'RALPH AVENUE',
#   'cross_street_2': 'HOWARD AVENUE',
#   'descriptor': 'Loud Music/Party',
#   'incident_address': '823 MADISON STREET',
#   'incident_zip': '11221',
#   'intersection_street_1': 'RALPH AVENUE',
#   'intersection_street_2': 'HOWARD AVENUE',
#   'landmark': 'MADISON STREET',
#   'latitude': '40.68789638499726',
#   'location': {'human_address': '{"address": "", "city": "", "state": "", '
#                                 '"zip": ""}',
#                'latitude': '40.68789638499726',
#                'longitude': '-73.92302703354021'},
#   'location_type': 'Residential Building/House',
#   'longitude': '-73.92302703354021',
#   'open_data_channel_type': 'MOBILE',
#   'park_borough': 'BROOKLYN',
#   'park_facility_name': 'Unspecified',
#   'status': 'In Progress',
#   'street_name': 'MADISON STREET',
#   'unique_key': '49782317',
#   'x_coordinate_state_plane': '1005597',
#   'y_coordinate_state_plane': '189905'}]

# %%
# Filter to only records created between January 1st 2020 and February 12th 2021 and use limit to override default 1000 records
complaints = response.get("erm2-nwe9", select="*", where = "created_date between '2020-01-01T20:00:00' and '2021-02-13T23:59:59'", limit=200000)

# %%
# Convert Json to dataframe
complaints_df = pd.DataFrame.from_records(complaints)

# %%
# Show length of dataframe to display 1k default was bypassed
len(complaints_df)
# Out:
# 200000

# %% [markdown]
# ## Clean the 311 Dataset

# %%
# Display first five records
complaints_df.head()
# Out:
#   unique_key             created_date              closed_date agency  \
# 0   45287028  2020-01-01T20:00:00.000  2020-01-02T21:00:00.000    DOT
# 1   45286187  2020-01-01T20:00:14.000  2020-01-03T14:18:19.000    HPD
# 2   45286499  2020-01-01T20:00:17.000  2020-01-02T06:50:41.000   NYPD
# 3   45288727  2020-01-01T20:00:37.000  2020-01-04T02:12:51.000    HPD
# 4   45286892  2020-01-01T20:01:43.000  2020-01-02T05:38:31.000   NYPD
#
#                                          agency_name          complaint_type  \
# 0                       Department of Transportation  Street Light Condition
# 1  Department of Housing Preservation and Develop...          HEAT/HOT WATER
# 2                    New York City Police Department     Noise - Residential
# 3  Department of Housing Preservation and Develop...          HEAT/HOT WATER
# 4                    New York City Police Department         Illegal Parking
#
#          descriptor incident_zip             intersection_street_1  \
# 0  Street Light Out        10452                SHAKESPEARE AVENUE
# 1    APARTMENT ONLY        11226                               NaN
# 2  Loud Music/Party        10039  MACOMBS DAM BRDG PEDESTRIAN PATH
# 3    APARTMENT ONLY        11211                               NaN
# 4   Blocked Hydrant        11378                         71 STREET
#
#     intersection_street_2  ...         landmark facility_type  \
# 0  CROSS BRONX EXPRESSWAY  ...              NaN           NaN
# 1                     NaN  ...              NaN           NaN
# 2      HARLEM RIVER DRIVE  ...         8 AVENUE           NaN
# 3                     NaN  ...              NaN           NaN
# 4               72 STREET  ...  CALDWELL AVENUE           NaN
#
#   bridge_highway_name bridge_highway_direction road_ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   bridge_highway_segment taxi_pick_up_location due_date vehicle_type  \
# 0                    NaN                   NaN      NaN          NaN
# 1                    NaN                   NaN      NaN          NaN
# 2                    NaN                   NaN      NaN          NaN
# 3                    NaN                   NaN      NaN          NaN
# 4                    NaN                   NaN      NaN          NaN
#
#   taxi_company_borough
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 41 columns]

# %%
# Display columns of dataframe
column_length_1 = len(complaints_df.columns)
print(complaints_df.columns)
print(f'-----------------------------')
print(f'The 311 dataset has {column_length_1} columns')
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'incident_zip', 'intersection_street_1',
#        'intersection_street_2', 'address_type', 'city', 'status',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'latitude', 'longitude',
#        'location', 'location_type', 'incident_address', 'street_name', 'bbl',
#        'cross_street_1', 'cross_street_2', 'landmark', 'facility_type',
#        'bridge_highway_name', 'bridge_highway_direction', 'road_ramp',
#        'bridge_highway_segment', 'taxi_pick_up_location', 'due_date',
#        'vehicle_type', 'taxi_company_borough'],
#       dtype='object')
# -----------------------------
# The 311 dataset has 41 columns

# %% [markdown]
# #### Remove columns
#
# * 'x_coordinate_state_plane'
# * 'y_coordinate_state_plane'
# * 'landmark'
# * 'facility_type'
# * 'bbl'
# * 'due_date'
# * 'park_borough'
# * 'taxi_pick_up_location'
# * 'bridge_highway_segment'
# * 'vehicle_type'
# * 'taxi_company_borough'
# * 'road_ramp'
# * 'bridge_highway_direction'
# * 'bridge_highway_name'
# * 'park_facility_name'

# %%
# Determine counts of NaN values in specific columns to determine which columns to drop
#complaints_df["column_name"].isna().sum()

drop_columns_01 = ['x_coordinate_state_plane', 'status','y_coordinate_state_plane', 'address_type', 'landmark', 'facility_type', 'bbl', 'due_date', 'park_borough', 'taxi_pick_up_location', 'bridge_highway_segment','vehicle_type', 'taxi_company_borough', 'road_ramp', 'bridge_highway_direction', 'bridge_highway_name', 'park_facility_name']
complaints_df = complaints_df.drop(labels=drop_columns_01, axis=1)

column_length_2 = len(complaints_df.columns)
print(f'After removing unnecessary columns the 311 dataset has {column_length_2} columns')
# Out:
# After removing unnecessary columns the 311 dataset has 24 columns

# %% [markdown]
# #### Merge columns

# %%
# Migrate all data into 'intersection_street_1' from 'cross_street_1 to account for missing values
complaints_df[['intersection_street_1','cross_street_1']] 
complaints_df['intersection_street_1'] = complaints_df['intersection_street_1'].fillna(complaints_df['cross_street_1'])

# Migrate all data into 'intersetction_street_2' from 'cross_street_2' to account for missing values
complaints_df[['intersection_street_2','cross_street_2']] 
complaints_df['intersection_street_2'] = complaints_df['intersection_street_2'].fillna(complaints_df['cross_street_2'])

# Drop duplicate cross-street columns
drop_columns_02 = ['cross_street_1', 'cross_street_2']
complaints_df = complaints_df.drop(labels=drop_columns_02, axis=1)

column_length_3 = len(complaints_df.columns)
print(f'After removing the duplicative columns the 311 dataset has {column_length_3} columns')
# Out:
# After removing the duplicative columns the 311 dataset has 22 columns

# %% [markdown]
# #### Rename columns

# %%
# Rename columns 'incident_zip' to 'zipcode' and 'open_data_channel_type' to 'channel'
complaints_df.rename(columns={'incident_zip': 'zipcode', 'open_data_channel_type': 'channel', 'intersection_street_1': 'cross_street_1', 'intersection_street_2': 'cross_street_2', 'resolution_action_updated_date': 'updated_date'}, inplace=True)

# %%
# Display final column list
complaints_df.columns.tolist()
# Out:
# ['unique_key',
#  'created_date',
#  'closed_date',
#  'agency',
#  'agency_name',
#  'complaint_type',
#  'descriptor',
#  'zipcode',
#  'cross_street_1',
#  'cross_street_2',
#  'city',
#  'resolution_description',
#  'updated_date',
#  'community_board',
#  'borough',
#  'channel',
#  'latitude',
#  'longitude',
#  'location',
#  'location_type',
#  'incident_address',
#  'street_name']

# %% [markdown]
# #### Account for data input method

# %%
# Convert all string values to lowercase
complaints_df = complaints_df.applymap(lambda s:s.lower() if type(s) == str else s)

# %% [markdown]
# #### Drop all rows where zipcode is Nan

# %%
# Remove the 7k rows that do not have a zipcode specified
complaints_df = complaints_df.dropna(subset=['zipcode'])

rows_after_clean = len(complaints_df)
print(f'After removing all rows with a NaN value under zipcode column, there were {rows_after_clean} rows (complaints) remaining')
# Out:
# After removing all rows with a NaN value under zipcode column, there were 193026 rows (complaints) remaining

# %% [markdown]
# #### Save cleaned dataframe to csv

# %%
complaints_df.to_csv("Output/clean_311.csv")
